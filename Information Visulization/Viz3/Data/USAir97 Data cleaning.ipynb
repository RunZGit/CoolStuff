# %% [markdown]
# ### This is the steps I took to clean the USAir97 data
# Library used:
# [Pandas](https://pandas.pydata.org): This is for data manipulations
# [FuzzyWuzzy](https://github.com/seatgeek/fuzzywuzzy):This is for fuzzy string matching
#
# Dataset referenced:
# [Airports](https://github.com/mwgg/Airports): Github page
# [Open flights](https://openflights.org/data.html): Open source project

# %%
import pandas as pd
from fuzzywuzzy import process
import os

# %%
with open("./USAir97.net.txt") as f:
    ## You want to replaced the "" from the airport names before spliting
    content = f.read().replace('"', "").split("\n")
## Those are the airports
nodes = content[1:333]

# %%
"""
    A little preprocessing.
    Convert Intll, and Intl to international during split.
    You might be able to use regex instead. 
    Other things you could try to replace:
        muni -> municipal
        afb -> Air force base
    You may find more
"""
airports = []
for node in nodes:
    splited = node.split()
    name = splited[1:-3]
    replaceString = ["Intll", "Intl"]
    for st in replaceString:
        if st in name:
            name[name.index(st)] = "International"
    airports.append([splited[0], " ".join(name), splited[-3], splited[-2]])

# %%
"""
I used two data base for reference, and loaded them here:
https://github.com/mwgg/Airports
https://openflights.org/data.html

"""

df1 = pd.read_json("./airports.json")
df2 = pd.read_csv("./airports.dat.txt")
df2.columns =  ["Airport ID", "Name","City","Country","IATA","ICAO","Latitude","Longitude","Altitude","Timezone","DST","Tz database time zone","Type","Source"]

usefulColums1 = ["name", "city", "state", "country", "lat", "lon", 'code']
usefulColums2 = ["Name","City", "Country", "Latitude","Longitude","IATA"]

df1 = df1[usefulColums1]
df2=df2[usefulColums2]

df2.columns = ["name", "city", "country", "lat", "lon", 'code']

# %% [markdown]
# Compile a list of possible airport names, and created a reverse lookup dictionary, to reduce the runtime
#
# I appened the city name to the end of the airport name to increase our chance of matching

# %%
choices1 = []
lookup1 = {}
index = 0
for n, c in df1[["name", "city"]].values:
    choices1.append(str(n)+" "+str(c))
    lookup1[str(n)+" "+str(c)] = index
    index+=1

choices2 = []
lookup2 = {}
index = 0
for n, c in df2[["name", "city"]].values:
    choices2.append(str(n)+" "+str(c))
    lookup2[str(n)+" "+str(c)] = index
    index+=1

# %% [markdown]
# For each airport we will try to obtain a match with both database

# %%
print("Match result 1:")
print(process.extract("Wiley Post-Will Rogers Mem", choices1, limit=5))
print("Match result 2:")
print(process.extract("Wiley Post-Will Rogers Mem", choices2, limit=5))
# Out:
# Match result 1:
# [('Wiley Post Will Rogers Memorial Airport Barrow', 90), ('Will Rogers World Airport Oklahoma City', 86), (' Port Moller', 58), (' Shillong', 56), (' Ipota', 54)]
# Match result 2:
# [('Wiley Post Will Rogers Memorial Airport Barrow', 90), ('Kingston Norman Rogers Airport Kingston', 86), ('Jackson-Medgar Wiley Evers International Airport Jackson', 86), ('Henry Post Army Air Field (Fort Sill) Fort Sill', 86), ('Will Rogers World Airport Oklahoma City', 86)]

# %%
cleaned = []
for airport in airports:
    name = airport[1]
    ## in here we are only extracting the best one, using reverse lookup 
    ## to find out the index of the row for later use.
    match1 = process.extractOne(name, choices1)
    match2 = process.extractOne(name, choices2)
    to_append = [match1[0], lookup1[match1[0]], match1[1], match2[0], lookup2[match2[0]], match2[1]]
    cleaned.append(airport+to_append)
## Move everything into a pandas database
new_df = pd.DataFrame(cleaned, columns=["Id","Name", "x", "y", "m1Name", "m1Idx", "m1Score", "m2Name", "m2Idx", "m2Score"])

# %%
new_df.head()
# Out:
#    Id                        Name       x       y  \
# 0   1  Wiley Post-Will Rogers Mem  0.4407  0.0910
# 1   2                   Deadhorse  0.4830  0.1014
# 2   3         Ralph Wien Memorial  0.4110  0.1330
# 3   4     Fairbanks International  0.4861  0.1528
# 4   5                        Nome  0.3965  0.1557
#
#                                            m1Name   m1Idx  m1Score  \
# 0  Wiley Post Will Rogers Memorial Airport Barrow   406.0       90
# 1                   Deadhorse Airport Prudhoe Bay  2659.0       90
# 2            Ralph Wien Memorial Airport Kotzebue  2268.0       90
# 3       Fairbanks International Airport Fairbanks   894.0       90
# 4                               Nome Airport Nome  2227.0       90
#
#                                            m2Name   m2Idx  m2Score City State  \
# 0  Wiley Post Will Rogers Memorial Airport Barrow  3355.0       90  NaN   NaN
# 1                     Deadhorse Airport Deadhorse  3404.0       90  NaN   NaN
# 2            Ralph Wien Memorial Airport Kotzebue  3477.0       90  NaN   NaN
# 3       Fairbanks International Airport Fairbanks  3612.0       90  NaN   NaN
# 4                               Nome Airport Nome  3399.0       90  NaN   NaN
#
#    lat lon
# 0  0.0   0
# 1  0.0   0
# 2  0.0   0
# 3  0.0   0
# 4  0.0   0

# %% [markdown]
# ### Now we will have manual step
# Once the names are matched, I have to mannualy to check the results. The good news is, 88% of the matching are correct, or at least one of the database has a good matching result. I had to hand code about 40 of them. This is where you will discover some of the airport might not exists anymore. Or the airport was matched to another coountry.
# Some of the airports might still exists in the database, then you can just findout which row it was in, instead of mannully fill in the information. Hence the last 4 columns in the df above.

# %%
last_df = pd.read_excel("./matched_airports.xlsx")

# %% [markdown]
# ### Now the fun part:
# We will compare the score on each matching, and used the one with higher score.
# Please note that chancging the order of the database will make the code below useless.
# Since one database has the states the other one does not, but they both share the IATA code, so you can use the IATA code found from second dataabse to findout the corresponding row in the first database. If it does not exists, then I will use "N/A" as a placeholder

# %%
formatted = []
for row in last_df.values:
    basic = []
    for i in row[:4]:
        basic.append(i)
    if not row[-1]==0:
        #Manualy added result
        basic.append(row[1])
        for i in row[-4:]:
            basic.append(i)
    else:
        # Auto matched
        if row[6] >= row[9]:
            cur_row = df1.iloc[int(row[5])]
        else:
            cur_row = df1[df1['code'] == df2[["code"]].iloc[int(row[8])].values[0]]
            if cur_row.size==0:
                cur_row = df2.iloc[int(row[8])]
                cur_row['state'] = "N/A"
                cur_row = cur_row[usefulColums1].values
            else:
                cur_row = cur_row.values[0]
        for val in cur_row[:-1]:
            basic.append(val)
    formatted.append(basic)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda/lib/python3.6/site-packages/pandas/core/series.py:769: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.loc[key] = value

# %%
final_result = pd.DataFrame(formatted)

# %%
final_result
# Out:
#        0                                        1       2       3  \
# 0      1               Wiley Post-Will Rogers Mem  0.4407  0.0910
# 1      2                                Deadhorse  0.4830  0.1014
# 2      3                      Ralph Wien Memorial  0.4110  0.1330
# 3      4                  Fairbanks International  0.4861  0.1528
# 4      5                                     Nome  0.3965  0.1557
# 5      6                               St Mary\'s  0.4074  0.1791
# 6      7                                    Aniak  0.4266  0.1837
# 7      8                  Anchorage International  0.4752  0.1876
# 8      9                                 Tuluksak  0.4193  0.1883
# 9     10                                 Akiachak  0.4169  0.1901
# 10    11                                    Akiak  0.4180  0.1901
# 11    12                                 Kwethluk  0.4169  0.1911
# 12    13                                   Bethel  0.4149  0.1913
# 13    14                                Napaskiak  0.4152  0.1921
# 14    15                                 Napakiak  0.4142  0.1922
# 15    16                  Merle K (Mudhole) Smith  0.4982  0.1941
# 16    17                              Tuntutuliak  0.4107  0.1956
# 17    18                                      Eek  0.4140  0.1967
# 18    19                               Kongiganak  0.4096  0.1992
# 19    20                             Kwigillingok  0.4082  0.2003
# 20    21                                Quinhagak  0.4147  0.2011
# 21    22                                  Yakutat  0.5278  0.2035
# 22    23                               Dillingham  0.4319  0.2079
# 23    24                              King Salmon  0.4413  0.2114
# 24    25                                 Gustavus  0.5480  0.2138
# 25    26                     Juneau International  0.5537  0.2145
# 26    27                                   Kodiak  0.4625  0.2203
# 27    28                           St Paul Island  0.3722  0.2259
# 28    29                                    Sitka  0.5497  0.2270
# 29    30                              Port Heiden  0.4312  0.2278
# ..   ...                                      ...     ...     ...
# 302  303             Corpus Christi International  0.7425  0.5067
# 303  304                     Laredo International  0.7325  0.5089
# 304  305         Sarasota/Bradenton International  0.8186  0.5103
# 305  306                 Palm Beach International  0.8312  0.5171
# 306  307          Southwest Florida International  0.8227  0.5185
# 307  308          Rio Grande Valley International  0.7417  0.5215
# 308  309            Mc Allen Miller International  0.7388  0.5220
# 309  310  Fort Lauderdale/Hollywood International  0.8309  0.5230
# 310  311                      Miami International  0.8302  0.5256
# 311  312                                    Lihue  0.4276  0.5621
# 312  313                   Honolulu International  0.4348  0.5684
# 313  314                                  Molokai  0.4390  0.5700
# 314  315                                  Kapalua  0.4412  0.5718
# 315  316                                  Kahului  0.4424  0.5724
# 316  317                                    Lanai  0.4398  0.5735
# 317  318               Keahole-Kona International  0.4444  0.5835
# 318  319                       Hilo International  0.4495  0.5837
# 319  320                         Rafael Hernandez  0.8972  0.5954
# 320  321           Luis Munoz Marin International  0.9029  0.5959
# 321  322                             Cyril E King  0.9082  0.5969
# 322  323                  Eugenio Maria De Hostos  0.8971  0.5977
# 323  324                                Mercedita  0.9001  0.6000
# 324  325                       Alexander Hamilton  0.9091  0.6029
# 325  326                           Johnston Atoll  0.3757  0.6122
# 326  327                     Saipan International  0.1479  0.6276
# 327  328                       Rota International  0.1454  0.6366
# 328  329                       Guam International  0.1431  0.6432
# 329  330                         Babelthuap/Koror  0.0909  0.7017
# 330  331                  Pago Pago International  0.3697  0.9090
# 331  332                              West Tinian  0.1473  0.6288
#
#                                                    4                  5  \
# 0            Wiley Post Will Rogers Memorial Airport             Barrow
# 1                                  Deadhorse Airport        Prudhoe Bay
# 2                        Ralph Wien Memorial Airport           Kotzebue
# 3                    Fairbanks International Airport          Fairbanks
# 4                                       Nome Airport               Nome
# 5                                             Alaska        Saint Marys
# 6                                      Aniak Airport             Bethel
# 7                    Anchorage International Airport          Anchorage
# 8                                           Tuluksak           Tuluksak
# 9                                           Akiachak           Akiachak
# 10                                     Akiak Airport             Bethel
# 11                                  Kwethluk Airport           Kwethluk
# 12                                    Bethel Airport             Bethel
# 13                                            Alaska          Napaskiak
# 14                                         Napaskiak           Napakiak
# 15                     Merle K Mudhole Smith Airport            Cordova
# 16                                       Tuntutuliak        Tuntutuliak
# 17                                       Eek Airport                Eek
# 18                                            Alaska         Kongiganak
# 19                                      Kwigillingok       Kwigillingok
# 20                                         Quinhagak          Quinhagak
# 21                                   Yakutat Airport            Yakutat
# 22                      Dillingham Municipal Airport         Dillingham
# 23                               King Salmon Airport        King Salmon
# 24                                  Gustavus Airport           Gustavus
# 25                      Juneau International Airport             Juneau
# 26                                    Kodiak Airport             Kodiak
# 27                                 Saint Paul Island  Saint Paul Island
# 28                                     Sitka Airport              Sitka
# 29                               Port Heiden Airport        Port Heiden
# ..                                               ...                ...
# 302             Corpus Christi International Airport     Corpus Christi
# 303                     Laredo International Airport             Laredo
# 304                       Sarasota Bradenton Airport           Sarasota
# 305                 Palm Beach International Airport    West Palm Beach
# 306          Southwest Florida International Airport         Fort Myers
# 307              Grande Valley International Airport          Harlingen
# 308                     Miller International Airport            Mcallen
# 309  Fort Lauderdale Hollywood International Airport        Dania Beach
# 310                      Miami International Airport              Miami
# 311                                    Lihue Airport              Lihue
# 312                   Honolulu International Airport           Honolulu
# 313                                  Molokai Airport           Hoolehua
# 314                        Kapalua West Maui Airport            Lahaina
# 315                                  Kahului Airport            Kahului
# 316                                    Lanai Airport         Lanai City
# 317                Kailua-Kona International Airport        Kailua Kona
# 318                       Hilo International Airport               Hilo
# 319                         Rafael Hernandez Airport          Aguadilla
# 320                         Luis Munoz Marin Airport           Carolina
# 321               Cyril E King International Airport   Charlotte Amalie
# 322                  Eugenio Maria de Hostos Airport           Mayaguez
# 323                                Mercedita Airport        Coto Laurel
# 324            Henry E Rohlson International Airport       Frederiksted
# 325                           Johnston Atoll Airport    Johnston Island
# 326                     Saipan International Airport             Saipan
# 327                       Rota International Airport               Rota
# 328          Antonio B Won Pat International Airport            Hagåtña
# 329                                    Koror Airport              Koror
# 330                  Pago Pago International Airport          Pago Pago
# 331                                           Tinian             Tinian
#
#                             6                         7        8           9
# 0                      Alaska             United States  71.2892 -156.772000
# 1                      Alaska             United States  70.1975 -148.458000
# 2                      Alaska             United States  66.8893 -162.610000
# 3                      Alaska             United States  64.8183 -147.866000
# 4                      Alaska             United States  64.5125 -165.445000
# 5                      Alaska             United States  62.0503 -163.179000
# 6                      Alaska             United States  61.5742 -159.535000
# 7                      Alaska             United States  61.1767 -149.961000
# 8                      Alaska             United States  61.0959 -160.968000
# 9                      Alaska             United States  60.9057 -161.424000
# 10                     Alaska             United States  60.8866 -161.218000
# 11                     Alaska             United States     60.8 -161.450000
# 12                     Alaska             United States  60.7788 -161.847000
# 13                     Alaska             United States  60.7049 -161.766000
# 14                     Alaska             United States  60.7049 -161.766000
# 15                     Alaska             United States  60.4924 -145.475000
# 16                     Alaska             United States  60.3432 -162.664000
# 17                     Alaska             United States  60.2167 -162.017000
# 18                     Alaska             United States  62.8903 -149.054000
# 19                     Alaska             United States  59.9077 -163.026000
# 20                     Alaska             United States  59.7511 -161.908000
# 21                     Alaska             United States  59.5103 -139.668000
# 22                     Alaska             United States  59.0445 -158.513000
# 23                     Alaska             United States  58.6775 -156.655000
# 24                     Alaska             United States  58.4246 -135.707000
# 25                     Alaska             United States  58.3598 -134.583000
# 26                     Alaska             United States  57.7545 -152.512000
# 27                     Alaska             United States  57.1667 -170.217000
# 28                     Alaska             United States  57.0535 -135.366000
# 29                     Alaska             United States  56.9667 -158.633000
# ..                        ...                       ...      ...         ...
# 302                     Texas             United States  27.7747  -97.501900
# 303                     Texas             United States  27.5431  -99.455500
# 304                   Florida             United States  27.3868  -82.551600
# 305                   Florida             United States  26.6909  -80.088900
# 306                   Florida             United States  26.5228  -81.753100
# 307                     Texas             United States  26.2216  -97.663000
# 308                     Texas             United States  26.1813  -98.240400
# 309                   Florida             United States  26.0722  -80.135400
# 310                   Florida             United States  25.7953  -80.272700
# 311                    Hawaii             United States  21.9782 -159.351000
# 312                    Hawaii             United States  21.3358 -157.919000
# 313                    Hawaii             United States  21.1557 -157.094000
# 314                    Hawaii             United States  20.9619 -156.676000
# 315                    Hawaii             United States  20.8926 -156.441000
# 316                    Hawaii             United States  20.7909 -156.951000
# 317                    Hawaii             United States  19.7334 -156.039000
# 318                    Hawaii             United States  19.7126 -155.042000
# 319               Puerto Rico             United States   18.496  -67.135700
# 320               Puerto Rico             United States  18.4367  -66.009500
# 321         US Virgin Islands             United States  18.3333  -64.966700
# 322               Puerto Rico             United States  18.2531  -67.148900
# 323               Puerto Rico             United States  18.0116  -66.566400
# 324         US Virgin Islands             United States  17.6988  -64.797700
# 325                       N/A            Johnston Atoll  16.7286 -169.533997
# 326  Northern Mariana Islands             United States  15.1333  145.717000
# 327  Northern Mariana Islands             United States  14.1667  145.250000
# 328                      Guam             United States  13.4833  144.796000
# 329                     Koror                     Palau  7.35743  134.547000
# 330            American Samoa             United States -14.3242 -170.706000
# 331                    Veneto  Northern Mariana Islands  45.0039   12.268600
#
# [332 rows x 10 columns]

# %% [markdown]
# ## Another Manual step
# Now most of our data are cleaned, I had to go through each of them again for sanity check. This is also the time I find out the states for the N/As.

# %%
final_result.to_csv("final_cleaned.csv")

# %% [markdown]
# ## Done!!
# Now we have the final dataset below

# %%
new_result = pd.read_csv("final.csv", index_col=0)

# %%
new_result
# Out:
#       ID                                 old_name       x       y  \
# 0      1               Wiley Post-Will Rogers Mem  0.4407  0.0910
# 1      2                                Deadhorse  0.4830  0.1014
# 2      3                      Ralph Wien Memorial  0.4110  0.1330
# 3      4                  Fairbanks International  0.4861  0.1528
# 4      5                                     Nome  0.3965  0.1557
# 5      6                               St Mary\'s  0.4074  0.1791
# 6      7                                    Aniak  0.4266  0.1837
# 7      8                  Anchorage International  0.4752  0.1876
# 8      9                                 Tuluksak  0.4193  0.1883
# 9     10                                 Akiachak  0.4169  0.1901
# 10    11                                    Akiak  0.4180  0.1901
# 11    12                                 Kwethluk  0.4169  0.1911
# 12    13                                   Bethel  0.4149  0.1913
# 13    14                                Napaskiak  0.4152  0.1921
# 14    15                                 Napakiak  0.4142  0.1922
# 15    16                  Merle K (Mudhole) Smith  0.4982  0.1941
# 16    17                              Tuntutuliak  0.4107  0.1956
# 17    18                                      Eek  0.4140  0.1967
# 18    19                               Kongiganak  0.4096  0.1992
# 19    20                             Kwigillingok  0.4082  0.2003
# 20    21                                Quinhagak  0.4147  0.2011
# 21    22                                  Yakutat  0.5278  0.2035
# 22    23                               Dillingham  0.4319  0.2079
# 23    24                              King Salmon  0.4413  0.2114
# 24    25                                 Gustavus  0.5480  0.2138
# 25    26                     Juneau International  0.5537  0.2145
# 26    27                                   Kodiak  0.4625  0.2203
# 27    28                           St Paul Island  0.3722  0.2259
# 28    29                                    Sitka  0.5497  0.2270
# 29    30                              Port Heiden  0.4312  0.2278
# ..   ...                                      ...     ...     ...
# 302  303             Corpus Christi International  0.7425  0.5067
# 303  304                     Laredo International  0.7325  0.5089
# 304  305         Sarasota/Bradenton International  0.8186  0.5103
# 305  306                 Palm Beach International  0.8312  0.5171
# 306  307          Southwest Florida International  0.8227  0.5185
# 307  308          Rio Grande Valley International  0.7417  0.5215
# 308  309            Mc Allen Miller International  0.7388  0.5220
# 309  310  Fort Lauderdale/Hollywood International  0.8309  0.5230
# 310  311                      Miami International  0.8302  0.5256
# 311  312                                    Lihue  0.4276  0.5621
# 312  313                   Honolulu International  0.4348  0.5684
# 313  314                                  Molokai  0.4390  0.5700
# 314  315                                  Kapalua  0.4412  0.5718
# 315  316                                  Kahului  0.4424  0.5724
# 316  317                                    Lanai  0.4398  0.5735
# 317  318               Keahole-Kona International  0.4444  0.5835
# 318  319                       Hilo International  0.4495  0.5837
# 319  320                         Rafael Hernandez  0.8972  0.5954
# 320  321           Luis Munoz Marin International  0.9029  0.5959
# 321  322                             Cyril E King  0.9082  0.5969
# 322  323                  Eugenio Maria De Hostos  0.8971  0.5977
# 323  324                                Mercedita  0.9001  0.6000
# 324  325                       Alexander Hamilton  0.9091  0.6029
# 325  326                           Johnston Atoll  0.3757  0.6122
# 326  327                     Saipan International  0.1479  0.6276
# 327  328                       Rota International  0.1454  0.6366
# 328  329                       Guam International  0.1431  0.6432
# 329  330                         Babelthuap/Koror  0.0909  0.7017
# 330  331                  Pago Pago International  0.3697  0.9090
# 331  332                              West Tinian  0.1473  0.6288
#
#                                                 name               city  \
# 0            Wiley Post Will Rogers Memorial Airport             Barrow
# 1                                  Deadhorse Airport        Prudhoe Bay
# 2                        Ralph Wien Memorial Airport           Kotzebue
# 3                    Fairbanks International Airport          Fairbanks
# 4                                       Nome Airport               Nome
# 5                                             Alaska        Saint Marys
# 6                                      Aniak Airport             Bethel
# 7                    Anchorage International Airport          Anchorage
# 8                                           Tuluksak           Tuluksak
# 9                                           Akiachak           Akiachak
# 10                                     Akiak Airport             Bethel
# 11                                  Kwethluk Airport           Kwethluk
# 12                                    Bethel Airport             Bethel
# 13                                            Alaska          Napaskiak
# 14                                         Napaskiak           Napakiak
# 15                     Merle K Mudhole Smith Airport            Cordova
# 16                                       Tuntutuliak        Tuntutuliak
# 17                                       Eek Airport                Eek
# 18                                            Alaska         Kongiganak
# 19                                      Kwigillingok       Kwigillingok
# 20                                         Quinhagak          Quinhagak
# 21                                   Yakutat Airport            Yakutat
# 22                      Dillingham Municipal Airport         Dillingham
# 23                               King Salmon Airport        King Salmon
# 24                                  Gustavus Airport           Gustavus
# 25                      Juneau International Airport             Juneau
# 26                                    Kodiak Airport             Kodiak
# 27                                 Saint Paul Island  Saint Paul Island
# 28                                     Sitka Airport              Sitka
# 29                               Port Heiden Airport        Port Heiden
# ..                                               ...                ...
# 302             Corpus Christi International Airport     Corpus Christi
# 303                     Laredo International Airport             Laredo
# 304                       Sarasota Bradenton Airport           Sarasota
# 305                 Palm Beach International Airport    West Palm Beach
# 306          Southwest Florida International Airport         Fort Myers
# 307              Grande Valley International Airport          Harlingen
# 308                     Miller International Airport            Mcallen
# 309  Fort Lauderdale Hollywood International Airport        Dania Beach
# 310                      Miami International Airport              Miami
# 311                                    Lihue Airport              Lihue
# 312                   Honolulu International Airport           Honolulu
# 313                                  Molokai Airport           Hoolehua
# 314                        Kapalua West Maui Airport            Lahaina
# 315                                  Kahului Airport            Kahului
# 316                                    Lanai Airport         Lanai City
# 317                Kailua-Kona International Airport        Kailua Kona
# 318                       Hilo International Airport               Hilo
# 319                         Rafael Hernandez Airport          Aguadilla
# 320                         Luis Munoz Marin Airport           Carolina
# 321               Cyril E King International Airport   Charlotte Amalie
# 322                  Eugenio Maria de Hostos Airport           Mayaguez
# 323                                Mercedita Airport        Coto Laurel
# 324            Henry E Rohlson International Airport       Frederiksted
# 325                           Johnston Atoll Airport    Johnston Island
# 326                     Saipan International Airport             Saipan
# 327                       Rota International Airport               Rota
# 328          Antonio B Won Pat International Airport            Hagåtña
# 329                                    Koror Airport              Koror
# 330                  Pago Pago International Airport          Pago Pago
# 331                                           Tinian             Tinian
#
#                         state                   country       lat         lon
# 0                      Alaska             United States  71.28920 -156.772000
# 1                      Alaska             United States  70.19750 -148.458000
# 2                      Alaska             United States  66.88930 -162.610000
# 3                      Alaska             United States  64.81830 -147.866000
# 4                      Alaska             United States  64.51250 -165.445000
# 5                      Alaska             United States  62.05030 -163.179000
# 6                      Alaska             United States  61.57420 -159.535000
# 7                      Alaska             United States  61.17670 -149.961000
# 8                      Alaska             United States  61.09590 -160.968000
# 9                      Alaska             United States  60.90570 -161.424000
# 10                     Alaska             United States  60.88660 -161.218000
# 11                     Alaska             United States  60.80000 -161.450000
# 12                     Alaska             United States  60.77880 -161.847000
# 13                     Alaska             United States  60.70490 -161.766000
# 14                     Alaska             United States  60.70490 -161.766000
# 15                     Alaska             United States  60.49240 -145.475000
# 16                     Alaska             United States  60.34320 -162.664000
# 17                     Alaska             United States  60.21670 -162.017000
# 18                     Alaska             United States  62.89030 -149.054000
# 19                     Alaska             United States  59.90770 -163.026000
# 20                     Alaska             United States  59.75110 -161.908000
# 21                     Alaska             United States  59.51030 -139.668000
# 22                     Alaska             United States  59.04450 -158.513000
# 23                     Alaska             United States  58.67750 -156.655000
# 24                     Alaska             United States  58.42460 -135.707000
# 25                     Alaska             United States  58.35980 -134.583000
# 26                     Alaska             United States  57.75450 -152.512000
# 27                     Alaska             United States  57.16670 -170.217000
# 28                     Alaska             United States  57.05350 -135.366000
# 29                     Alaska             United States  56.96670 -158.633000
# ..                        ...                       ...       ...         ...
# 302                     Texas             United States  27.77470  -97.501900
# 303                     Texas             United States  27.54310  -99.455500
# 304                   Florida             United States  27.38680  -82.551600
# 305                   Florida             United States  26.69090  -80.088900
# 306                   Florida             United States  26.52280  -81.753100
# 307                     Texas             United States  26.22160  -97.663000
# 308                     Texas             United States  26.18130  -98.240400
# 309                   Florida             United States  26.07220  -80.135400
# 310                   Florida             United States  25.79530  -80.272700
# 311                    Hawaii             United States  21.97820 -159.351000
# 312                    Hawaii             United States  21.33580 -157.919000
# 313                    Hawaii             United States  21.15570 -157.094000
# 314                    Hawaii             United States  20.96190 -156.676000
# 315                    Hawaii             United States  20.89260 -156.441000
# 316                    Hawaii             United States  20.79090 -156.951000
# 317                    Hawaii             United States  19.73340 -156.039000
# 318                    Hawaii             United States  19.71260 -155.042000
# 319               Puerto Rico             United States  18.49600  -67.135700
# 320               Puerto Rico             United States  18.43670  -66.009500
# 321         US Virgin Islands             United States  18.33330  -64.966700
# 322               Puerto Rico             United States  18.25310  -67.148900
# 323               Puerto Rico             United States  18.01160  -66.566400
# 324         US Virgin Islands             United States  17.69880  -64.797700
# 325                    Hawaii             United States  16.72860 -169.533997
# 326  Northern Mariana Islands             United States  15.13330  145.717000
# 327  Northern Mariana Islands             United States  14.16670  145.250000
# 328                      Guam             United States  13.48330  144.796000
# 329                     Koror                     Palau   7.35743  134.547000
# 330            American Samoa             United States -14.32420 -170.706000
# 331                    Veneto  Northern Mariana Islands  45.00390   12.268600
#
# [332 rows x 10 columns]
